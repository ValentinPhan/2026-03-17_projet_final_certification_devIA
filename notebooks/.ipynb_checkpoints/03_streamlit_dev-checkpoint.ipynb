# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\Utilisateur\anaconda3\Lib\site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (10.4.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.29.6-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: rich<14,>=10.14.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Utilisateur\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading protobuf-5.29.6-cp310-abi3-win_amd64.whl (435 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.32.0
#     Uninstalling protobuf-6.32.0:
#       Successfully uninstalled protobuf-6.32.0
# Successfully installed protobuf-5.29.6
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Utilisateur\anaconda3\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.6 which is incompatible.

# %%
"""
# My first app
Here's our first attempt at using data to create a table:
"""

import streamlit as st
import pandas as pd
df = pd.DataFrame({
  'first column': [1, 2, 3, 4],
  'second column': [10, 20, 30, 40]
})

df
# Out:
#    first column  second column
# 0             1             10
# 1             2             20
# 2             3             30
# 3             4             40

# %%
import streamlit as st
import pandas as pd

st.write("Here's our first attempt at using data to create a table:")
st.write(pd.DataFrame({
    'first column': [1, 2, 3, 4],
    'second column': [10, 20, 30, 40]
}))
# Out:
# 2026-04-01 11:08:47.856
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Utilisateur\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
import streamlit as st
import numpy as np

dataframe = np.random.randn(10, 20)
st.dataframe(dataframe)
# Out:
# DeltaGenerator()

# %%
import streamlit as st
import numpy as np
import pandas as pd

dataframe = pd.DataFrame(
    np.random.randn(10, 20),
    columns=('col %d' % i for i in range(20)))

st.dataframe(dataframe.style.highlight_max(axis=0))
# Out:
# DeltaGenerator()
